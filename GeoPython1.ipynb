# %% [markdown]
# <a href="https://colab.research.google.com/github/eholmes877/PythonGIS/blob/main/GeoPython1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1+1
# Out:
# 2

# %%
5*7
# Out:
# 35

# %%
import math

# %%
math.sin(3)
# Out:
# 0.1411200080598672

# %%
math.sqrt(4)
# Out:
# 2.0

# %% [markdown]
# Question 2.1

# %%
math.sin(math.pi)
# Out:
# 1.2246467991473532e-16

# %%
print(math.sqrt(4))
# Out:
# 2.0

# %%
print("The square root of 4 is", math.sqrt(4))
# Out:
# The square root of 4 is 2.0

# %%
temp_celsius = 10.0
temp_celsius
# Out:
# 10.0

# %%
print("Temperature in Fahrenheit:", 9/5 * temp_celsius + 32)
# Out:
# Temperature in Fahrenheit: 50.0

# %% [markdown]
# Question 2.2

# %%
pothole_case_naming = "Todd"
pothole_case_naming
# Out:
# 'Todd'

# %%
temp_celsius = 17.0
print("temperature in Celsius is now:", temp_celsius)
# Out:
# temperature in Celsius is now: 17.0

# %%
tempFahrenheit = 9/5 * temp_celsius + 32
print("temperature in Celsius:", temp_celsius, "and in Fahrenheit:", tempFahrenheit)
# Out:
# temperature in Celsius: 17.0 and in Fahrenheit: 62.6

# %% [markdown]
# Question 2.3

# %%
myvar1 = "Tomato"
myvar2 = "Potato"
print(myvar1 + myvar2)
print(5*myvar1)
print(myvar1-myvar2)
# Out:
# TomatoPotato
# TomatoTomatoTomatoTomatoTomato
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_510/3047144187.py in <cell line: 0>()
#       3 print(myvar1 + myvar2)
#       4 print(5*myvar1)
# ----> 5 print(myvar1-myvar2)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
